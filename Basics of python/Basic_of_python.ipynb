# %% [markdown]
# Python_Programming Assignment

# %%
import sys, math, random
import numpy as np
import pandas as pd

# %% [markdown]
# `sys`          # Access Python runtime details and system-specific parameters
#
# `math`        # Provides mathematical functions
#
# `random`       # Generate random numbers, selections, shuffling
#
# `numpy` as np  # Numerical computing: arrays, vectors, matrices, fast math ops
#
# `pandas` as pd # Data analysis: tables (DataFrames), CSV/Excel handling

# %% [markdown]
# `Exercise 1: Prime Numbers`
#
# Write a Python program that checks whether a given number is prime or not. A prime number is a natural number greater than 1 that has no positive divisors other than 1 and itself.

# %%
try:
    n = int(input("Enter a number: "))

    if n <= 1:
        print("Not Prime")
    else:
        for i in range(2, int(n**0.5) + 1):
            if n % i == 0:
                print("Not Prime")
                break
        else:
            print("Prime")

except ValueError:
    print("Invalid entry, please provide a number")
# Out:
# Enter a number: 1234
# Not Prime

# %% [markdown]
# `Exercise 2: Product of Random Numbers`
#
# Develop a Python program that generates two random numbers and asks the user to enter the product of these numbers. The program should then check if the user's answer is correct and display an appropriate message.

# %%
import random  # Generate random numbers/selection

# %%
num1 = random.randint(1, 10)
num2 = random.randint(1, 10)

# %%
try:
    user_answer = int(input(f"What is the product of {num1} and {num2}? "))

    if user_answer == num1 * num2:
        print("Correct Answer! Well done ")
    else:
        print(f"Incorrect. \nThe correct answer is {num1 * num2}")

except ValueError:
    print("Invalid entry, please provide a number")
# Out:
# What is the product of 10 and 8? 80
# Correct Answer! Well done

# %% [markdown]
# `Exercise 3: Squares of Even/Odd Numbers`
#
# Create a Python script that prints the squares of all even or odd numbers within the range of 100 to 200. Choose either even or odd numbers and document your choice in the code.

# %%
# Squares of Even or Odd Numbers based on user choice

choice = input("Enter 'even' or 'odd': ").strip().lower()

for num in range(100, 201):
    if choice == "even" and num % 2 == 0:
        print(f"{num}^2 = {num**2}")
    elif choice == "odd" and num % 2 != 0:
        print(f"{num}^2 = {num**2}")
# Out:
# Enter 'even' or 'odd': 150

# %% [markdown]
# `Exercise 4: Word counter`
#
# write a program to count the number of words in a given text.

# %%
# Taking input from user
input_text = input("Enter the text: ")
# Out:
# Enter the text: I am Omkar Gutal

# %%
words = input_text.split()

# %%
word_count = {} # # Dictionary to store word counts

for word in words:
    word_count[word] = word_count.get(word, 0) + 1 # store count of word in word_count

# Display result
for word, count in word_count.items():
    print(f"'{word}': {count}")
# Out:
# 'I': 1
# 'am': 1
# 'Omkar': 1
# 'Gutal': 1

# %% [markdown]
# `Exercise 5: Check for Palindrome`
#
# Write a Python function called is_palindrome that takes a string as input and returns True if the string is a palindrome, and False otherwise. A palindrome is a word, phrase, number, or other sequence of characters that reads the same forward and backward, ignoring spaces, punctuation, and capitalization.

# %%
def is_palindrome(text: str) -> bool:
    cleaned = ''.join(ch.lower() for ch in text if ch.isalnum()) # convert to lower case and Ignores spaces, punctuation, symbols
    return cleaned == cleaned[::-1] # Check palindrome

# %%
user_text = input("Enter a string to check if it's a palindrome: ") # user Input

if is_palindrome(user_text):
    print("True! It's a palindrome")
else:
    print("False! It's not a palindrome")
# Out:
# Enter a string to check if it's a palindrome: Madam
# True! It's a palindrome
